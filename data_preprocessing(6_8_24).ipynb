# %%
import pandas as pd
df = pd.read_excel('Top_Genres_Data_with_Top_maps_cleaned.xlsx')

# %%
select=df[['Genre','Map Name','Description','Age Rating','Tags']]
select
# Out:
#                Genre                                Map Name  \
# 0                PvP                               BOX PVP 📦
# 1                PvP  🐐 GO GOATED! Zone Wars 🌀 *NEW WEAPONS*
# 2                PvP                  The Pit - Free For All
# 3                PvP                    CRAZY RED VS BLUE 🔴🔵
# 4                PvP                      TILTED ZONE WARS ⭐
# ..               ...                                     ...
# 278        Simulator     🌲 SPEED REALISTICS (2v2) - FINEST 🌲
# 279        Simulator     💯 RED VS BLUE 🥶 RUMBLE - Zero Build
# 280  Team Deathmatch                    YOUTUBER RED VS BLUE
# 281  Team Deathmatch                  AMAZING RED VS BLUE 🔴🔵
# 282  Team Deathmatch                          Save The World
#
#                                            Description Age Rating  \
# 0    📦 CLASSIC BOX FIGHTS🐠 BOXED LIKE A FISH🤯 200 P...  Teen / 12
# 1    🐐 4 Teams Battle 🐐🌀 Classic Zone Wars Game 🌀👥S...   Teen / 7
# ...

# %%
final = select[select['Description'] != 'NOT FOUND']
final
# Out:
#                Genre                                Map Name  \
# 0                PvP                               BOX PVP 📦
# 1                PvP  🐐 GO GOATED! Zone Wars 🌀 *NEW WEAPONS*
# 2                PvP                  The Pit - Free For All
# 3                PvP                    CRAZY RED VS BLUE 🔴🔵
# 4                PvP                      TILTED ZONE WARS ⭐
# ..               ...                                     ...
# 276        Simulator                      SUPERSTORE TYCOON🛒
# 279        Simulator     💯 RED VS BLUE 🥶 RUMBLE - Zero Build
# 280  Team Deathmatch                    YOUTUBER RED VS BLUE
# 281  Team Deathmatch                  AMAZING RED VS BLUE 🔴🔵
# 282  Team Deathmatch                          Save The World
#
#                                            Description Age Rating  \
# 0    📦 CLASSIC BOX FIGHTS🐠 BOXED LIKE A FISH🤯 200 P...  Teen / 12
# 1    🐐 4 Teams Battle 🐐🌀 Classic Zone Wars Game 🌀👥S...   Teen / 7
# ...

# %%
final.to_csv('training(6-8-24).csv')
