# %%
game_tags = [
    "2D", "1v1", "2v2", "3v3", "4v4", "5v5", "6v6", "7v7", "8v8",
    "Action", "Adventure", "Aim Course", "Arcade", "Arena", "Artistic",
    "Atmospheric", "Attack", "Base", "Base Building", "Battle", "Battle Royale",
    "Board Game", "Boss Battle", "Boxfight", "Building", "Capture the Flag",
    "Card Game", "Casual", "Choices Matter", "Classes", "Clicker", "Co-op",
    "Collection", "Competitive", "Crafting", "Creatures", "Defend",
    "Difficulty: Easy", "Difficulty: Medium", "Difficulty: Hard",
    "Difficulty: Very Hard", "Difficulty: Ultra Hard", "Difficulty: Impossible",
    "Duo", "Driver Simulator", "Economy", "Edit Course", "Educational",
    "Episodic", "Escape", "Event", "Exploration", "Explosives", "Farming Simulator",
    "Fashion", "Fighting", "Fortnitemares", "Free for All", "Friendly", "Funny",
    "Gun Fight", "Gun Game", "Hardcore", "Heroes", "Horror", "Hub", "Infection",
    "Jam System", "Just for Fun", "King of the Hill", "Memes", "Melee", "Minigame",
    "Mining", "MOBA", "Moving", "Music", "Mystery", "Nonlinear", "Objective",
    "One in the Chamber", "One Life", "One Shot", "Open World", "Parkour",
    "Party Game", "Party World", "Patchwork", "Peaceful", "Pinball", "Point Capture",
    "Physics", "Pixel Art", "Platformer", "Practice", "Prop", "Prop Hunt", "Puzzle",
    "PVE", "PVP", "Quiz", "Race", "Respawn", "Retro", "Roguelike", "Role Playing",
    "RPG", "Rounds", "Runner", "Sandbox", "Search & Destroy", "Seasonal", "Secrets",
    "Sequel", "Series", "Shooter", "Shop", "Show", "Side Scroller", "Simulator",
    "Single Player", "Skillrun", "Skills", "Sniper", "Solo", "Space", "Sports",
    "Squad", "Stealth", "Story", "Strategy", "Survival", "Survival Horror",
    "Team Free for All", "Teams", "Timed", "Top-Down", "Tower Defense", "Training",
    "Trios", "Trivia", "Turn-Based", "Tutorial", "Tycoon", "Unbalanced Teams",
    "Visual Novel", "Winterfest", "Word Games", "ZoneWars"
]

# %%
import pandas as pd

# %%
test_df = pd.read_csv("evalset.csv")

# %%
test_df.columns
# Out:
# Index(['Game ', 'Description', 'Age Rating', 'Tags'], dtype='object')

# %%
test_df
# Out:
#                                Game   \
# 0                 Festival Jam Stage
# 1                            高性能 1v1
# 2                   1V1 MAP INFINITE
# 3                  ماب المعرقين PRO💯
# 4                Piece Control 3v3 🎯
# 5               Pit - Custom Weapons
# 6   TILTED ZONE WARS (ALL WEAPONS) ⭐
# 7                 TILTED ZONE WARS ⭐
# 8                 Festival Jam Stage
# 9          1v1 Build Fights! [4.6.4]
# 10              1v1 With Every Gun 🔫
# 11            The Pit - Free For All
# 12                OnlyUp Fortnite! 🌄
# 13         🛡️ ARMORED RED VS BLUE 🔴🔵
# 14               👑 SIGMA BOXFIGHTS 📦
#
#                                           Description    Age Rating  \
# 0   Explore the Jam Stage festival grounds to find...     Teen / 12
# 1                                     1v1 Build Fight     Teen / 12
# 2   FIRST PERSON MODE ( NEW )Always NewUpdated Wea...     Teen / 12
# 3   2-20 players compete, either team of the two t...     Teen / 12
# ...

# %%
import pandas as pd
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
client = OpenAI()

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('evalset.csv')

def rag_flow(prompt):
    completion = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {"role": "system", "content": "You are a assistant, skilled in suggesting game tags."},
        {"role": "user", "content": prompt}
      ]
    )

    return completion.choices[0].message.content

base_prompt = """{}
Based on the above game data, for this game title,game description, age rating suggest a single game tag out of {}. Return the game tag only and no other text.
The format of the response should be:
1. Tag1
2. Tag2
3. Tag3
4. Tag4
5. Tag5
{}
"""
suggested_tags = []
for index, row in test_df.iterrows():
    age_rating = row['Age Rating']
    filtered_df = train_df[train_df['Age Rating'] == age_rating]
    retrieved_text = filtered_df.to_string()
    input_text = row[['Game ', 'Description', 'Age Rating']].to_string(index=False, header=False)
    prompt = base_prompt.format(retrieved_text, game_tags, input_text)
    suggested_tag = rag_flow(prompt)
    suggested_tags.append(suggested_tag)

    print("Actual Tag:", row['Tags'])
    print("Generated Titles:\n", suggested_tag)

test_df['Generated Tags'] = suggested_tags
# Out:
# Actual Tag: music,
# Generated Titles:
#  - Music
# - Party Game
# Actual Tag: 1v1, practice,
# Generated Titles:
#  1v1
# Building
# Practice
# Competitive
# Actual Tag: 1v1, pvp, zonewars, practice,
# Generated Titles:
#  - 1v1
# - Practice
# - Zonewars
# - Building
# - Competitive
# Actual Tag: team deathmatch, action, capture the flag,
# Generated Titles:
#  - Team Free for All
# Actual Tag: boxfight, pvp, practice, competitive,
# Generated Titles:
#  - Boxfight
# - PvP
# - Practice
# - Competitive
# - 3v3
# Actual Tag: free for all, practice, pvp, respawn,
# Generated Titles:
#  1. Free for All
# 2. Practice
# 3. PVP
# 4. Respawn
# 5. Action
# Actual Tag: zonewars, practice, free for all, pvp,
# Generated Titles:
#  zonewars
# practice
# pvp
# free for all
# Actual Tag: practice, zonewars, pvp, free for all,
# Generated Titles:
#  - Zonewars
# - Practice
# - Pvp
# - Free for all
# - Action
# Actual Tag: music,
# Generated Titles:
#  - Music
# - Party Game
# - Jam System
# ...

# %%
test_df
# Out:
#                                Game   \
# 0                 Festival Jam Stage
# 1                            高性能 1v1
# 2                   1V1 MAP INFINITE
# 3                  ماب المعرقين PRO💯
# 4                Piece Control 3v3 🎯
# 5               Pit - Custom Weapons
# 6   TILTED ZONE WARS (ALL WEAPONS) ⭐
# 7                 TILTED ZONE WARS ⭐
# 8                 Festival Jam Stage
# 9          1v1 Build Fights! [4.6.4]
# 10              1v1 With Every Gun 🔫
# 11            The Pit - Free For All
# 12                OnlyUp Fortnite! 🌄
# 13         🛡️ ARMORED RED VS BLUE 🔴🔵
# 14               👑 SIGMA BOXFIGHTS 📦
#
#                                           Description    Age Rating  \
# 0   Explore the Jam Stage festival grounds to find...     Teen / 12
# 1                                     1v1 Build Fight     Teen / 12
# 2   FIRST PERSON MODE ( NEW )Always NewUpdated Wea...     Teen / 12
# 3   2-20 players compete, either team of the two t...     Teen / 12
# ...

# %%
output_csv = 'rag_generated_tags.csv'
test_df.to_csv(output_csv, index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("rag_generated_tags.csv")

# %%
df.head()
# Out:
#                  Game                                         Description  \
# 0   Festival Jam Stage  Explore the Jam Stage festival grounds to find...
# 1              高性能 1v1                                    1v1 Build Fight
# 2     1V1 MAP INFINITE  FIRST PERSON MODE ( NEW )Always NewUpdated Wea...
# 3    ماب المعرقين PRO💯  2-20 players compete, either team of the two t...
# 4  Piece Control 3v3 🎯  🥇 Leaderboard📝 Intense Boxfight Piece Control ...
#
#   Age Rating                                         Tags  \
# 0  Teen / 12                                       music,
# 1  Teen / 12                               1v1, practice,
# 2  Teen / 12                1v1, pvp, zonewars, practice,
# 3  Teen / 12  team deathmatch, action, capture the flag,
# 4  Teen / 12        boxfight, pvp, practice, competitive,
#
#                                        Generated Tag
# 0  ['Music', 'Party Game', 'Competitive', 'Leader...
# 1     ['1v1', 'building', 'practice', 'competitive']
# ...

# %%
for entry in df['Generated Tag']:
    print(type(entry))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
